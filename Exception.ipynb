# %% [markdown]
# Syntax Errors

# %%
while True print('Hello world')
# Out:
#   File "<ipython-input-4-2b688bc740d7>", line 1
#     while True print('Hello world')
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# Exceptions

# %%
10 * (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-0b280f36835c> in <module>()
# ----> 1 10 * (1/0)
#
# ZeroDivisionError: division by zero

# %%
4 + spam*3

# %% [markdown]
# Handling Exceptions

# %%
while True:
     try:
        x = int(input("Please enter a number: "))
         break
     except ValueError:
         print("Oops!  That was no valid number.  Try again...")
# Out:
#   File "<ipython-input-6-2d3edfab92ac>", line 4
#     break
#     ^
# IndentationError: unexpected indent

# %%
def this_fails():
     x = 1/0

try:
     this_fails()
 except ZeroDivisionError as err:
     print('Handling run-time error:', err)
# Out:
#   File "<ipython-input-7-269f41724e74>", line 6
#     except ZeroDivisionError as err:
#                                     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Raising Exceptions

# %%
raise NameError('HiThere')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-72c183edb298> in <module>()
# ----> 1 raise NameError('HiThere')
#
# NameError: HiThere

# %%
try:
     raise NameError('HiThere')
 except NameError:
     print('An exception flew by!')
     raise
# Out:
#   File "<ipython-input-9-b0422a3796e5>", line 3
#     except NameError:
#                      ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Exception Chaining

# %%
def func():
     raise IOError

try:
     func()
 except IOError as exc:
     raise RuntimeError('Failed to open database') from exc
# Out:
#   File "<ipython-input-10-4ee0fcb02556>", line 6
#     except IOError as exc:
#                           ^
# IndentationError: unindent does not match any outer indentation level

# %%
try:

    open('database.sqlite')

except OSError:

    raise RuntimeError from None
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-85acde149291> in <module>()
#       5 except OSError:
#       6
# ----> 7     raise RuntimeError from None
#
# RuntimeError:

# %% [markdown]
# User Defined Exceptions

# %%
class Error(Exception):
    """Base class for exceptions in this module."""
    pass

class InputError(Error):
    """Exception raised for errors in the input.

    Attributes:
        expression -- input expression in which the error occurred
        message -- explanation of the error
    """

    def __init__(self, expression, message):
        self.expression = expression
        self.message = message

class TransitionError(Error):
    """Raised when an operation attempts a state transition that's not
    allowed.

    Attributes:
        previous -- state at beginning of transition
        next -- attempted new state
        message -- explanation of why the specific transition is not allowed
    """

    def __init__(self, previous, next, message):
        self.previous = previous
        self.next = next
        self.message = message

# %% [markdown]
# Predefined Clean-ups

# %%
for line in open("myfile.txt"):
    print(line, end="")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-5eb9bb8784e2> in <module>()
# ----> 1 for line in open("myfile.txt"):
#       2     print(line, end="")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'

# %%
with open("myfile.txt") as f:
    for line in f:
        print(line, end="")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-6a090e47786f> in <module>()
# ----> 1 with open("myfile.txt") as f:
#       2     for line in f:
#       3         print(line, end="")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'
